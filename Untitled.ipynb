# %%
input_file = 'list.csv'

with open(input_file, encoding='UTF-8') as f:
    rows = csv.reader(f,delimiter=",",lineterminator="\n")
    next(rows, None)
    for row in rows:
        user = {}
        user['username']import requests
import json
import os

class telegram_chatbot():
    
    def __init__(self, token):
        self.token = token
        self.base = "https://api.telegram.org/bot{}/".format(self.token)

    def get_updates(self, offset=None):
        url = self.base + "getUpdates?timeout=100"
        if offset:
            url = url + "&offset={}".format(offset + 1)
        r = requests.get(url)
        return json.loads(r.content)

    def send_message(self, msg, chat_id):
        url = self.base + "sendMessage?chat_id={}&text={}".format(chat_id, msg)
        if msg is not None:
            requests.get(url)

    def make_reply(self,msg):
        reply = None
        if msg is not None:
            reply = msg
        return reply
    
    def make_plot(self,msg):
        list_ = msg.split(',')
        if(len(list_) == 3):
            getPlot(str(list_[1]), str(list_[2]))
            return
    
    def getPlot(tick, timeframe):
        
        command = 'curl -s -X POST https://api.telegram.org/bot' + str(self.token) + '/sendPhoto -F chat_id=' + str(chat_id) + ' -F photo=@' + str(os.path.abspath(os.getcwd())) + '/screenshot.png'
        subprocess.call(command.split(' '))
        return   


token = '1500206305:AAFQIy_ZPFuKoACWWEOa-IbmUMV6L968pkg'
bot = telegram_chatbot(token)

update_id = None
while True:
    updates = bot.get_updates(offset=update_id)
    updates = updates["result"]
    if updates:
        for item in updates:
            update_id = item["update_id"]
            try:
                message = str(item["message"]["text"])
            except:
                message = None
            from_ = item["message"]["from"]["id"]
            if (message.find('/getPlot') != -1):
                bot.make_plot(message)
            elif (message.find('/help') != -1):
                bot.send_message('Syntax:\nUse this function to get plots /getPlot,Ticker1,Ticker2,StartTime,EndTime\nNote: Dates should be in detail DD/MM/YYYY/hh/mm format', from_)
            else:
                bot.send_message('Syntax:\nUse this function to get plots /getPlot,Ticker1,Ticker2,StartTime,EndTime\nNote: Dates should be in detail DD/MM/YYYY/hh/mm format', from_)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-1ec4c8233722> in <module>
#      44 update_id = None
#      45 while True:
# ---> 46     updates = bot.get_updates(offset=update_id)
#      47     updates = updates["result"]
#      48     if updates:
#
# <ipython-input-16-1ec4c8233722> in get_updates(self, offset)
#      13         if offset:
#      14             url = url + "&offset={}".format(offset + 1)
# ---> 15         r = requests.get(url)
#      16         return json.loads(r.content)
#      17
#
# /usr/lib/python3/dist-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/lib/python3/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/lib/python3/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /usr/lib/python3/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /usr/lib/python3/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/lib/python3/dist-packages/six.py in raise_from(value, from_value)
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# /usr/lib/python3.8/http/client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# /usr/lib/python3.8/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /usr/lib/python3.8/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /usr/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# /usr/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import os
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
import requests
import json
import subprocess

path = os.path.abspath(os.getcwd())


class TradingViewBot:
    def __init__(self):
        self.bot = webdriver.Firefox()

    def login(self):
        bot = self.bot
        bot.get("file:///"+ str(path)+ "/index.html")
        time.sleep(10)
                      
    def getScreen(self):
        self.bot.save_screenshot(str(path) + '/screenshot.png')
        
    def close(self):
        self.bot.close()

class telegram_chatbot():
    
    def __init__(self, token):
        self.token = token
        self.base = "https://api.telegram.org/bot{}/".format(self.token)

    def get_updates(self, offset=None):
        url = self.base + "getUpdates?timeout=100"
        if offset:
            url = url + "&offset={}".format(offset + 1)
        r = requests.get(url)
        return json.loads(r.content)

    def send_message(self, msg, chat_id):
        url = self.base + "sendMessage?chat_id={}&text={}".format(chat_id, msg)
        if msg is not None:
            requests.get(url)

    def make_reply(self,msg):
        reply = None
        if msg is not None:
            reply = msg
        return reply
    
    def getHtml(self, symbol, interval):

        html = """
<html>
<head>
<script type="text/javascript" src="https://s3.tradingview.com/tv.js">
</script>
</head>
<body>
<div class="tradingview-widget-container" id="tradingview_c39ad"></div>
<script>
LoadChart("""+ "\"" + str(symbol) + "\"" + ',' + "\"" + str(interval) + "\"" + """);
function LoadChart(symbol, interval){
new TradingView.widget(
  {
  "width": 980,
  "height": 610,
  "symbol": symbol,
  "interval": interval,
  "timezone": "Etc/UTC",
  "theme": "light",
  "style": "1",
  "locale": "in",
  "toolbar_bg": "#f1f3f6",
  "enable_publishing": false,
  "allow_symbol_change": true,
  "container_id": "tradingview_c39ad"
	});
}
</script>
</body>
</html>
"""
        with open(str(path)+ "/index.html", "w+") as file:
            file.write(html)

    
    def botFunctions(self,symbol, interval):
        self.getHtml(symbol, interval)
        instanc = TradingViewBot()
        instanc.login()
        instanc.getScreen()
        instanc.close()
    
    def getPlot(self,symbol, interval, chat_id):
        self.botFunctions(symbol, interval)
        command = 'curl -s -X POST https://api.telegram.org/bot' + str(self.token) + '/sendPhoto -F chat_id=' + str(chat_id) + ' -F photo=@' + str(os.path.abspath(os.getcwd())) + '/screenshot.png'
        subprocess.call(command.split(' '))
        return   
    
    def make_plot(self,msg,from_):
        list_ = msg.split(',')
        if(len(list_) == 3):
            self.getPlot(str(list_[1]), str(list_[2]),from_)
            return
    
#symbol = "NASDAQ:AMZN"
#interval = "D"

token = '1500206305:AAFQIy_ZPFuKoACWWEOa-IbmUMV6L968pkg'
bot = telegram_chatbot(token)

update_id = None
while True:
    updates = bot.get_updates(offset=update_id)
    updates = updates["result"]
    if updates:
        for item in updates:
            update_id = item["update_id"]
            try:
                message = str(item["message"]["text"])
            except:
                message = None
            from_ = item["message"]["from"]["id"]
            if (message.find('/getPlot') != -1):
                bot.make_plot(message,from_)
            elif (message.find('/help') != -1):
                bot.send_message('Syntax:\nUse this function to get plots /getPlot,Ticker1,Ticker2,StartTime,EndTime\nNote: Dates should be in detail DD/MM/YYYY/hh/mm format', from_)
            else:
                bot.send_message('Syntax:\nUse this function to get plots /getPlot,Ticker1,Ticker2,StartTime,EndTime\nNote: Dates should be in detail DD/MM/YYYY/hh/mm format', from_)

# %%
# Automated Trading Bot

# %%
# Telegram Group bot

from telethon.sync import TelegramClient
from telethon.tl.functions.messages import GetDialogsRequest
from telethon.tl.types import InputPeerEmpty, InputPeerChannel, InputPeerUser
from telethon.errors.rpcerrorlist import PeerFloodError, UserPrivacyRestrictedError
from telethon.tl.functions.channels import InviteToChannelRequest
import sys
import csv
import traceback
import time
import random

api_id = '1600663566'
api_hash = 'AAFSiFoGJw9FpR5K2Nr-4IpZQdrxZ5SMIn0'
phone = '+918124992738'
client = TelegramClient(phone, api_id, api_hash)

client.connect()
if not client.is_user_authorized():
    client.send_code_request(phone)
    client.sign_in(phone, input('Enter the code: '))

input_file = sys.argv[1]
users = []
with open(input_file, encoding='UTF-8') as f:
    rows = csv.reader(f,delimiter=",",lineterminator="\n")
    next(rows, None)
    for row in rows:
        user = {}
        user['username'] = row[0]
        user['id'] = int(row[1])
        user['access_hash'] = int(row[2])
        user['name'] = row[3]
        users.append(user)

chats = []
last_date = None
chunk_size = 200
groups=[]

result = client(GetDialogsRequest(
             offset_date=last_date,
             offset_id=0,
             offset_peer=InputPeerEmpty(),
             limit=chunk_size,
             hash = 0
         ))
chats.extend(result.chats)

for chat in chats:
    try:
        if chat.megagroup== True:
            groups.append(chat)
    except:
        continue

print('Choose a group to add members:')
i=0
for group in groups:
    print(str(i) + '- ' + group.title)
    i+=1

g_index = input("Enter a Number: ")
target_group=groups[int(g_index)]

target_group_entity = InputPeerChannel(target_group.id,target_group.access_hash)

mode = int(input("Enter 1 to add by username or 2 to add by ID: "))

n = 0

for user in users:
    n += 1
    if n % 50 == 0:
        time.sleep(900)
    try:
        print ("Adding {}".format(user['id']))
        if mode == 1:
            if user['username'] == "":
                continue
            user_to_add = client.get_input_entity(user['username'])
        elif mode == 2:
            user_to_add = InputPeerUser(user['id'], user['access_hash'])
        else:
            sys.exit("Invalid Mode Selected. Please Try Again.")
        client(InviteToChannelRequest(target_group_entity,[user_to_add]))
        print("Waiting for 60-180 Seconds...")
        time.sleep(random.randrange(60, 180))
    except PeerFloodError:
        print("Getting Flood Error from telegram. Script is stopping now. Please try again after some time.")
    except UserPrivacyRestrictedError:
        print("The user's privacy settings do not allow you to do this. Skipping.")
    except:
        traceback.print_exc()
        print("Unexpected Error")
        continue
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-7-209a7e50e7a4> in <module>
#      15 api_hash = 'AAFSiFoGJw9FpR5K2Nr-4IpZQdrxZ5SMIn0'
#      16 phone = '+918124992738'
# ---> 17 client = TelegramClient(phone, api_id, api_hash)
#      18
#      19 client.connect()
#
# ~/.local/lib/python3.8/site-packages/telethon/client/telegrambaseclient.py in __init__(self, session, api_id, api_hash, connection, use_ipv6, proxy, local_addr, timeout, request_retries, connection_retries, retry_delay, auto_reconnect, sequential_updates, flood_sleep_threshold, raise_last_call_error, device_model, system_version, app_version, lang_code, system_lang_code, loop, base_logger)
#     280         if (not session.server_address or
#     281                 (':' in session.server_address) != use_ipv6):
# --> 282             session.set_dc(
#     283                 DEFAULT_DC_ID,
#     284                 DEFAULT_IPV6_IP if self._use_ipv6 else DEFAULT_IPV4_IP,
#
# ~/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py in set_dc(self, dc_id, server_address, port)
#     166     def set_dc(self, dc_id, server_address, port):
#     167         super().set_dc(dc_id, server_address, port)
# --> 168         self._update_session_table()
#     169
#     170         # Fetch the auth_key corresponding to this data center
#
# ~/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py in _update_session_table(self)
#     192         # some more work before being able to save auth_key's for
#     193         # multiple DCs. Probably done differently.
# --> 194         c.execute('delete from sessions')
#     195         c.execute('insert or replace into sessions values (?,?,?,?,?)', (
#     196             self._dc_id,
#
# OperationalError: database is locked

# %%
from selenium import webdriver

browser = webdriver.Firefox()

url = "https://www.google.com/maps/place/Lucky+Dhaba/@30.653792,76.8165233,17z/data=!3m1!4b1!4m5!3m4!1s0x390feb3e3de1a031:0x862036ab85567f75!8m2!3d30.653792!4d76.818712"
browser.get(url)

# review titles / username / Person who reviews
review_titles = browser.find_elements_by_class_name("section-review-title")

print([a.text for a in review_titles])

# review text / what did they think
review_text = browser.find_elements_by_class_name("section-review-review-content")

print([a.text for a in review_text])

# get the number of stars

stars = browser.find_elements_by_class_name("section-review-stars")

first_review_stars = stars[0]

active_stars = first_review_stars.find_elements_by_class_name("section-review-star-active")

print(f"the stars the first review got was {len(active_stars)}")
# Out:
# []
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-1852e749a77e> in <module>
#      20 stars = browser.find_elements_by_class_name("section-review-stars")
#      21
# ---> 22 first_review_stars = stars[0]
#      23
#      24 active_stars = first_review_stars.find_elements_by_class_name("section-review-star-active")
#
# IndexError: list index out of range

# %%
    def __init__(self, token):
        self.token = token
        self.base = "https://api.telegram.org/bot{}/".format(self.token)

    def get_updates(self, offset=None):
        url = self.base + "getUpdates?timeout=100"
        if offset:
            url = url + "&offset={}".format(offset + 1)
        r = requests.get(url)
        return json.loads(r.content)

    def send_message(self, msg, chat_id):
        url = self.base + "sendMessage?chat_id={}&text={}".format(chat_id, msg)
        if msg is not None:
            requests.get(url)
            
    def getUsers(self):
        
    
    def make_plot(self,msg,chat_id,val = 0):
        list_ = msg.split(' ')
        if(len(list_) == 2):
            symbol = str(list_[1])
            TradingBotActions(val=val, symbol=symbol)
            command = 'curl -s -X POST https://api.telegram.org/bot' + str(self.token) + '/sendPhoto -F chat_id=' + str(chat_id) + ' -F photo=@' + str(os.path.abspath(os.getcwd())) + '/screenshot.png'
            subprocess.call(command.split(' '))
            return
        elif(len(list_) == 3):
            symbol = str(list_[1])
            interval = str(list_[2])
            TradingBotActions(val=val, symbol=symbol, interval=interval)
            command = 'curl -s -X POST https://api.telegram.org/bot' + str(self.token) + '/sendPhoto -F chat_id=' + str(chat_id) + ' -F photo=@' + str(os.path.abspath(os.getcwd())) + '/screenshot.png'
            subprocess.call(command.split(' '))
            return
        elif(len(list_) == 4):
            symbol = str(list_[1])
            interval = str(list_[2])
            theme = str(list_[3])
            TradingBotActions(val=val, symbol = symbol, interval = interval, theme = theme)
            command = 'curl -s -X POST https://api.telegram.org/bot' + str(self.token) + '/sendPhoto -F chat_id=' + str(chat_id) + ' -F photo=@' + str(os.path.abspath(os.getcwd())) + '/screenshot.png'
            subprocess.call(command.split(' '))
            return
    
def BotFunctions(token):
    bot = TelegramBot(token)
    update_id = None
    while True:
        updates = bot.get_updates(offset=update_id)
        if('result' in updates):
            updates = updates["result"]
        if updates:
            for item in updates:
                update_id = item["update_id"]
                try:
                    if("message" in item):
                        if ('text' in item['message']):
                            message = str(item["message"]["text"])
                        else:
                            message = None
                    elif ("edited_message" in item):
                        if ('text' in item['message']):
                            message = str(item["edited_message"]["text"])
                        else:
                            message = None
                except:
                    message = None
                if("message" in item):
                    from_ = item["message"]["chat"]["id"]
                elif ("edited_message" in item):
                    from_ = item["edited_message"]["chat"]["id"]
                
                if (message != None):    
                    if (message.find('/matrix') != -1):
                        bot.make_plot(message,from_,0)
                
                    elif (message.find('/marvel') != -1):
                        bot.make_plot(message,from_,1)
                
                    elif (message.find('/help') != -1):
                        bot.send_message('Syntax:\nUse this function to get plots \n/<Plot-type>,<TickerSymbol>,<TimeFrame>\[Optional\],<Theme>\[Optional\]\nNote: \n<Plot-type>: marvel, matrix\n<TimeFrame>: 1-1440 (for minutes), D (for day), M (for Month)\n<Theme>: light, dark\n', from_)
                
                    elif (re.search("\\w+", message) == 0):
                            bot.send_message('Syntax:\nUse this function to get plots \n/<Plot-type>,<TickerSymbol>,<TimeFrame>\[Optional\],<Theme>\[Optional\]\nNote: \n<Plot-type>: marvel, matrix\n<TimeFrame>: 1-1440 (for minutes), D (for day), M (for Month)\n<Theme>: light, dark\n', from_)
                
token = '1585200585:AAHIrCjRW3D-16dSB9NX__o00GNo4TGZcr4'
BotFunctions(token)
# Out:
#   File "<ipython-input-2-5fd5ff97fc9f>", line 20
#     def make_plot(self,msg,chat_id,val = 0):
#     ^
# IndentationError: expected an indented block

# %%
from telethon import TelegramClient, sync
# Use your own values here
api_id = '2420653'
api_hash = 'cf6d7d2c4b0c95e7ffe555079871e579'

phone_number='+918124992738'
client = TelegramClient(None, api_id, api_hash)
client.start()
client.connect()

# get all the channels that I can access

print(client.get_dialogs())
chan = await client.get_dialogs()
channels = await {d.entity.username: d.entity
            for d in chan#client.get_dialogs()
            if d.is_channel}

# choose the one that I want list users from
channel = channels[0]

# get all the users and print them
for u in client.get_participants(channel):
    print(u.id, u.first_name, u.last_name, u.username)
# Out:
# <coroutine object DialogMethods.get_dialogs at 0x7fa2f2d7c440>
# <ipython-input-1-124e05245822>:8: RuntimeWarning: coroutine 'AuthMethods._start' was never awaited
#   client.start()
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# <ipython-input-1-124e05245822>:9: RuntimeWarning: coroutine 'TelegramBaseClient.connect' was never awaited
#   client.connect()
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# <ipython-input-1-124e05245822>:13: RuntimeWarning: coroutine 'DialogMethods.get_dialogs' was never awaited
#   print(client.get_dialogs())
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-1-124e05245822> in <module>
#      12
#      13 print(client.get_dialogs())
# ---> 14 chan = await client.get_dialogs()
#      15 channels = await {d.entity.username: d.entity
#      16             for d in chan#client.get_dialogs()
#
# ~/.local/lib/python3.8/site-packages/telethon/client/dialogs.py in get_dialogs(self, *args, **kwargs)
#     254                 archived = await client.get_dialogs(archived=True)
#     255         """
# --> 256         return await self.iter_dialogs(*args, **kwargs).collect()
#     257
#     258     get_dialogs.__signature__ = inspect.signature(iter_dialogs)
#
# ~/.local/lib/python3.8/site-packages/telethon/requestiter.py in collect(self)
#     111         """
#     112         result = helpers.TotalList()
# --> 113         async for message in self:
#     114             result.append(message)
#     115
#
# ~/.local/lib/python3.8/site-packages/telethon/requestiter.py in __anext__(self)
#      72             self.index = 0
#      73             self.buffer = []
# ---> 74             if await self._load_next_chunk():
#      75                 self.left = len(self.buffer)
#      76
#
# ~/.local/lib/python3.8/site-packages/telethon/client/dialogs.py in _load_next_chunk(self)
#      51     async def _load_next_chunk(self):
#      52         self.request.limit = min(self.left, _MAX_CHUNK_SIZE)
# ---> 53         r = await self.client(self.request)
#      54
#      55         self.total = getattr(r, 'count', len(r.dialogs))
#
# ~/.local/lib/python3.8/site-packages/telethon/client/users.py in __call__(self, request, ordered)
#      28 class UserMethods:
#      29     async def __call__(self: 'TelegramClient', request, ordered=False):
# ---> 30         return await self._call(self._sender, request, ordered=ordered)
#      31
#      32     async def _call(self: 'TelegramClient', sender, request, ordered=False):
#
# ~/.local/lib/python3.8/site-packages/telethon/client/users.py in _call(self, sender, request, ordered)
#      56         for attempt in retry_range(self._request_retries):
#      57             try:
# ---> 58                 future = sender.send(request, ordered=ordered)
#      59                 if isinstance(future, list):
#      60                     results = []
#
# ~/.local/lib/python3.8/site-packages/telethon/network/mtprotosender.py in send(self, request, ordered)
#     168         """
#     169         if not self._user_connected:
# --> 170             raise ConnectionError('Cannot send requests while disconnected')
#     171
#     172         if not utils.is_list_like(request):
#
# ConnectionError: Cannot send requests while disconnected

# %%
from telethon import TelegramClient

from telethon.tl.functions.contacts import ResolveUsernameRequest
from telethon.tl.functions.channels import GetAdminLogRequest

from telethon.tl.types import InputChannel
from telethon.tl.types import ChannelAdminLogEventsFilter
from telethon.tl.types import InputUserSelf
from telethon.tl.types import InputUser

# These example values won't work. You must get your own api_id and
# api_hash from https://my.telegram.org, under API Development.


client = TelegramClient(phone_number, api_id, api_hash)
client.session.report_errors = False
await client.connect()

if not client.is_user_authorized():
    client.send_code_request(phone_number)
    client.sign_in(phone_number, input('Enter the code: '))


#channel = client(ResolveUsernameRequest('tabe_eshgh')) # Your channel username

user = client(ResolveUsernameRequest('Nivethithan007')) # Your channel admin username

#print(user)

admins = [InputUserSelf(), InputUser(user.users[0].id, user.users[0].access_hash)] # admins
admins = [] # No need admins for join and leave and invite filters

filter = None # All events
# param: (join, leave, invite, ban, unban, kick, unkick, promote, demote, info, settings, pinned, edit, delete)
filter = ChannelAdminLogEventsFilter(True, True, True, False, False, False, False, False, False, False, False, False, False, False)

result = client(GetAdminLogRequest(InputChannel(channel.chats[0].id, channel.chats[0].access_hash), '', 0, 0, 10, filter, admins))
##print(result)

for _user in result.users:
    ##print(_user.id)
    with open(''.join(['users/', str(_user.id)]), 'w') as f:
        f.write(str(_user.id))
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-10-1aca8f33a81b> in <module>
#      13
#      14
# ---> 15 client = TelegramClient(phone_number, api_id, api_hash)
#      16 client.session.report_errors = False
#      17 await client.connect()
#
# ~/.local/lib/python3.8/site-packages/telethon/client/telegrambaseclient.py in __init__(self, session, api_id, api_hash, connection, use_ipv6, proxy, local_addr, timeout, request_retries, connection_retries, retry_delay, auto_reconnect, sequential_updates, flood_sleep_threshold, raise_last_call_error, device_model, system_version, app_version, lang_code, system_lang_code, loop, base_logger)
#     280         if (not session.server_address or
#     281                 (':' in session.server_address) != use_ipv6):
# --> 282             session.set_dc(
#     283                 DEFAULT_DC_ID,
#     284                 DEFAULT_IPV6_IP if self._use_ipv6 else DEFAULT_IPV4_IP,
#
# ~/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py in set_dc(self, dc_id, server_address, port)
#     166     def set_dc(self, dc_id, server_address, port):
#     167         super().set_dc(dc_id, server_address, port)
# --> 168         self._update_session_table()
#     169
#     170         # Fetch the auth_key corresponding to this data center
#
# ~/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py in _update_session_table(self)
#     192         # some more work before being able to save auth_key's for
#     193         # multiple DCs. Probably done differently.
# --> 194         c.execute('delete from sessions')
#     195         c.execute('insert or replace into sessions values (?,?,?,?,?)', (
#     196             self._dc_id,
#
# OperationalError: database is locked

# %%
import random
import sqlite3

def do_query(path, q, args=None, commit=False):
    """
    do_query - Run a SQLite query, waiting for DB in necessary

    Args:
        path (str): path to DB file
        q (str): SQL query
        args (list): values for `?` placeholders in q
        commit (bool): whether or not to commit after running query
    Returns:
        list of lists: fetchall() for the query
    """
    if args is None:
        args = []
    for attempt in range(100):
        try:
            con = sqlite3.connect(path)
            cur = con.cursor()
            cur.execute(q, args)
            ans = cur.fetchall()
            if commit:
                con.commit()
            cur.close()
            con.close()
            del cur
            del con
            return ans
        except sqlite3.OperationalError:
            time.sleep(random.randint(10, 30))
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-3014' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('database is locked')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 530, in _get_difference
#     where = await self.get_input_entity(types.PeerChannel(channel_id))
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 425, in get_input_entity
#     return self.session.get_input_entity(peer)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/memory.py", line 216, in get_input_entity
#     result = self.get_entity_rows_by_id(key, exact)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 323, in get_entity_rows_by_id
#     return self._execute(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 239, in _execute
#     return c.execute(stmt, values).fetchone()
# sqlite3.OperationalError: database is locked
# Task exception was never retrieved
# future: <Task finished name='Task-3023' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('database is locked')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 530, in _get_difference
#     where = await self.get_input_entity(types.PeerChannel(channel_id))
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 425, in get_input_entity
#     return self.session.get_input_entity(peer)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/memory.py", line 216, in get_input_entity
#     result = self.get_entity_rows_by_id(key, exact)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 323, in get_entity_rows_by_id
#     return self._execute(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 239, in _execute
#     return c.execute(stmt, values).fetchone()
# sqlite3.OperationalError: database is locked
# Task exception was never retrieved
# future: <Task finished name='Task-2929' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 530, in _get_difference
#     where = await self.get_input_entity(types.PeerChannel(channel_id))
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 455, in get_input_entity
#     channels = await self(functions.channels.GetChannelsRequest([
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-2938' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 530, in _get_difference
#     where = await self.get_input_entity(types.PeerChannel(channel_id))
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 455, in get_input_entity
#     channels = await self(functions.channels.GetChannelsRequest([
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-2984' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 530, in _get_difference
#     where = await self.get_input_entity(types.PeerChannel(channel_id))
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 455, in get_input_entity
#     channels = await self(functions.channels.GetChannelsRequest([
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-2955' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 530, in _get_difference
#     where = await self.get_input_entity(types.PeerChannel(channel_id))
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 455, in get_input_entity
#     channels = await self(functions.channels.GetChannelsRequest([
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-2994' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 530, in _get_difference
#     where = await self.get_input_entity(types.PeerChannel(channel_id))
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 455, in get_input_entity
#     channels = await self(functions.channels.GetChannelsRequest([
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-2981' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 530, in _get_difference
#     where = await self.get_input_entity(types.PeerChannel(channel_id))
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 455, in get_input_entity
#     channels = await self(functions.channels.GetChannelsRequest([
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-2989' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-2991' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-3003' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 530, in _get_difference
#     where = await self.get_input_entity(types.PeerChannel(channel_id))
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 455, in get_input_entity
#     channels = await self(functions.channels.GetChannelsRequest([
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-3015' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 530, in _get_difference
#     where = await self.get_input_entity(types.PeerChannel(channel_id))
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 455, in get_input_entity
#     channels = await self(functions.channels.GetChannelsRequest([
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-2718' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('database is locked')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 414, in _dispatch_update
#     await self.get_me(input_peer=True)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 156, in get_me
#     me = (await self(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: database is locked
# Task exception was never retrieved
# future: <Task finished name='Task-2828' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('database is locked')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 414, in _dispatch_update
#     await self.get_me(input_peer=True)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 156, in get_me
#     me = (await self(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: database is locked
# Task exception was never retrieved
# future: <Task finished name='Task-2728' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('database is locked')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 414, in _dispatch_update
#     await self.get_me(input_peer=True)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 156, in get_me
#     me = (await self(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: database is locked
# Task exception was never retrieved
# future: <Task finished name='Task-2839' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('database is locked')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 414, in _dispatch_update
#     await self.get_me(input_peer=True)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 156, in get_me
#     me = (await self(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: database is locked
# Task exception was never retrieved
# future: <Task finished name='Task-2924' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-2891' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('database is locked')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: database is locked
# Task exception was never retrieved
# future: <Task finished name='Task-2925' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-2736' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('database is locked')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: database is locked
# Task exception was never retrieved
# future: <Task finished name='Task-2760' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('database is locked')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: database is locked
# Task exception was never retrieved
# future: <Task finished name='Task-2729' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('database is locked')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: database is locked
# Task exception was never retrieved
# future: <Task finished name='Task-3132' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('database is locked')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 414, in _dispatch_update
#     await self.get_me(input_peer=True)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 156, in get_me
#     me = (await self(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: database is locked
# Task exception was never retrieved
# future: <Task finished name='Task-2807' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('database is locked')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: database is locked
# Task exception was never retrieved
# future: <Task finished name='Task-2737' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('database is locked')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: database is locked
# Task exception was never retrieved
# future: <Task finished name='Task-2739' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('database is locked')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: database is locked
# Task exception was never retrieved
# future: <Task finished name='Task-2759' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-2758' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('database is locked')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: database is locked

# %%
from telethon.sync import TelegramClient
from telethon.tl.functions.messages import GetDialogsRequest
from telethon.tl.types import InputPeerEmpty, InputPeerChannel, InputPeerUser
from telethon.errors.rpcerrorlist import PeerFloodError, UserPrivacyRestrictedError
from telethon.tl.functions.channels import InviteToChannelRequest
import sys
import csv
import traceback
import time
import asyncio

class TelegramBot:
    def __init__(self, api_id, api_hash, phone):
        self.api_id = api_id
        self.api_hash = api_hash
        self.phone = phone
    
    async def startClient(self):
        self.client = TelegramClient(self.phone, self.api_id, self.api_hash)
        await self.client.connect()
        
        if not await self.client.is_user_authorized():
            await self.client.send_code_request(self.phone)
            await self.client.sign_in(self.phone,  input('Enter the code: '))
        
    async def getUsersList(self):
        groups = await self.getChannelsList()
        all_members = []
        for i in range(len(groups)):
            target_group=groups[i]
            target_group_entity = InputPeerChannel(target_group.id,target_group.access_hash)    
            print('Fetching Members...' + str(target_group.id))
            all_participants = []
            try:
                all_participants = await client.get_participants(target_group, aggressive=True)
            except:
                continue
            all_members.append(all_participants)
            print('Saving In file...')
        with open("members.csv","w+",encoding='UTF-8') as f:
                writer = csv.writer(f,delimiter=",",lineterminator="\n")
                csv_dict = [row for row in csv.DictReader(f)]
                if len(csv_dict) == 0:
                    writer.writerow(['username','user id', 'access hash','name'])#,'group', 'group id'])
                for user in all_members:
                    if user.username:
                        username= user.username
                    else:
                        username= ""
                    if user.first_name:
                        first_name= user.first_name
                    else:
                        first_name= ""
                    if user.last_name:
                        last_name= user.last_name
                    else:
                        last_name= ""
                    name= (first_name + ' ' + last_name).strip()
                    writer.writerow([username,user.id,user.access_hash,name])#,target_group.title, target_group.id])      
        print('Members scraped successfully.')
     
    async def getChannelsList(self):
        chats = []
        last_date = None
        chunk_size = 200
        groups=[]
         
        result = await client(GetDialogsRequest(
                     offset_date=last_date,
                     offset_id=0,
                     offset_peer=InputPeerEmpty(),
                     limit=chunk_size,
                     hash = 0
                 ))
        chats.extend(result.chats)
        
        for chat in chats:
                try:
                    if chat.megagroup== True:
                        groups.append(chat)
                except:
                    continue
        
        input_file = 'groups.csv'
        with open(input_file,'w+',encoding='UTF-8') as f:
            writer = csv.writer(f,delimiter=",",lineterminator="\n")
            csv_dict = [row for row in csv.DictReader(f)]
            if len(csv_dict) == 0:
                writer.writerow(['group name','group id', 'access hash'])
            for group in groups:
                if group.title:
                    groupname = group.title
                else:
                    groupname = ""
                if group.id:
                    group_id = group.id
                else:
                    group_id = ""
                if group.access_hash:
                    access_hash = group.access_hash
                else:
                    access_hash = ""
                writer.writerow([groupname,group_id,access_hash])   
   
        return groups
        
    async def addMembers(self,group_id, group_access_hash):
        users = []
        input_file = 'members.csv'
        with open(input_file, 'w+', encoding='UTF-8') as f:
            rows = csv.reader(f,delimiter=",",lineterminator="\n")
            next(rows, None)
            for row in rows:
                user = {}
                user['username'] = row[0]
                user['id'] = int(row[1])
                user['access_hash'] = int(row[2])
                user['name'] = row[3]
                users.append(user)
                
        target_group_entity = InputPeerChannel(group_id,group_access_hash)
             
        for user in users:
            n += 1
            if n % 50 == 0:
                sleep(900)
            try:
                print ("Adding {}".format(user['id']))
                if user['username'] == "":
                        continue
                user_to_add = client.get_input_entity(user['username'])
                client(InviteToChannelRequest(target_group_entity,[user_to_add]))
                print("Waiting for 60-180 Seconds...")
                time.sleep(random.randrange(60, 180))
            except PeerFloodError:
                print("Getting Flood Error from telegram. Script is stopping now. Please try again after some time.")
            except UserPrivacyRestrictedError:
                print("The user's privacy settings do not allow you to do this. Skipping.")
            except:
                traceback.print_exc()
                print("Unexpected Error")
                continue

# Access variables Definition
api_id = 2420653
api_hash = 'cf6d7d2c4b0c95e7ffe555079871e579'
phone = '+918124992738'

# Group id
group_id = 1369115731
group_access_hash = '-4683049040197455615'

# Function Calls
telegrambot = TelegramBot(api_id, api_hash, phone)
await telegrambot.startClient()
await telegrambot.getChannelsList()
await telegrambot.getUsersList()
await telegrambot.addMembers(group_id, group_access_hash)
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-2901' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('database is locked')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 530, in _get_difference
#     where = await self.get_input_entity(types.PeerChannel(channel_id))
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 425, in get_input_entity
#     return self.session.get_input_entity(peer)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/memory.py", line 216, in get_input_entity
#     result = self.get_entity_rows_by_id(key, exact)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 323, in get_entity_rows_by_id
#     return self._execute(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 239, in _execute
#     return c.execute(stmt, values).fetchone()
# sqlite3.OperationalError: database is locked
# Task exception was never retrieved
# future: <Task finished name='Task-2902' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('database is locked')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 530, in _get_difference
#     where = await self.get_input_entity(types.PeerChannel(channel_id))
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 425, in get_input_entity
#     return self.session.get_input_entity(peer)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/memory.py", line 216, in get_input_entity
#     result = self.get_entity_rows_by_id(key, exact)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 323, in get_entity_rows_by_id
#     return self._execute(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 239, in _execute
#     return c.execute(stmt, values).fetchone()
# sqlite3.OperationalError: database is locked
# Task exception was never retrieved
# future: <Task finished name='Task-2918' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('database is locked')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 530, in _get_difference
#     where = await self.get_input_entity(types.PeerChannel(channel_id))
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 425, in get_input_entity
#     return self.session.get_input_entity(peer)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/memory.py", line 216, in get_input_entity
#     result = self.get_entity_rows_by_id(key, exact)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 323, in get_entity_rows_by_id
#     return self._execute(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 239, in _execute
#     return c.execute(stmt, values).fetchone()
# sqlite3.OperationalError: database is locked
# Task exception was never retrieved
# future: <Task finished name='Task-2930' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('database is locked')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 530, in _get_difference
#     where = await self.get_input_entity(types.PeerChannel(channel_id))
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 425, in get_input_entity
#     return self.session.get_input_entity(peer)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/memory.py", line 216, in get_input_entity
#     result = self.get_entity_rows_by_id(key, exact)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 323, in get_entity_rows_by_id
#     return self._execute(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 239, in _execute
#     return c.execute(stmt, values).fetchone()
# sqlite3.OperationalError: database is locked
# Task exception was never retrieved
# future: <Task finished name='Task-2939' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('database is locked')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 530, in _get_difference
#     where = await self.get_input_entity(types.PeerChannel(channel_id))
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 425, in get_input_entity
#     return self.session.get_input_entity(peer)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/memory.py", line 216, in get_input_entity
#     result = self.get_entity_rows_by_id(key, exact)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 323, in get_entity_rows_by_id
#     return self._execute(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 239, in _execute
#     return c.execute(stmt, values).fetchone()
# sqlite3.OperationalError: database is locked
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# <ipython-input-73-181727d2c070> in <module>
#     152 # Function Calls
#     153 telegrambot = TelegramBot(api_id, api_hash, phone)
# --> 154 await telegrambot.startClient()
#     155 await telegrambot.getChannelsList()
#     156 await telegrambot.getUsersList()
#
# <ipython-input-73-181727d2c070> in startClient(self)
#      18     async def startClient(self):
#      19         self.client = TelegramClient(self.phone, self.api_id, self.api_hash)
# ---> 20         await self.client.connect()
#      21
#      22         if not await self.client.is_user_authorized():
#
# ~/.local/lib/python3.8/site-packages/telethon/client/telegrambaseclient.py in connect(self)
#     512                     print('Failed to connect')
#     513         """
# --> 514         if not await self._sender.connect(self._connection(
#     515             self.session.server_address,
#     516             self.session.port,
#
# ~/.local/lib/python3.8/site-packages/telethon/network/mtprotosender.py in connect(self, connection)
#     123
#     124             self._connection = connection
# --> 125             await self._connect()
#     126             self._user_connected = True
#     127             return True
#
# ~/.local/lib/python3.8/site-packages/telethon/network/mtprotosender.py in _connect(self)
#     223         for attempt in retry_range(self._retries):
#     224             if not connected:
# --> 225                 connected = await self._try_connect(attempt)
#     226                 if not connected:
#     227                     continue  # skip auth key generation until we're connected
#
# ~/.local/lib/python3.8/site-packages/telethon/network/mtprotosender.py in _try_connect(self, attempt)
#     273         try:
#     274             self._log.debug('Connection attempt %d...', attempt)
# --> 275             await self._connection.connect(timeout=self._connect_timeout)
#     276             self._log.debug('Connection success!')
#     277             return True
#
# ~/.local/lib/python3.8/site-packages/telethon/network/connection/connection.py in connect(self, timeout, ssl)
#     242         Establishes a connection with the server.
#     243         """
# --> 244         await self._connect(timeout=timeout, ssl=ssl)
#     245         self._connected = True
#     246
#
# ~/.local/lib/python3.8/site-packages/telethon/network/connection/connection.py in _connect(self, timeout, ssl)
#     214
#     215         if not self._proxy:
# --> 216             self._reader, self._writer = await asyncio.wait_for(
#     217                 asyncio.open_connection(
#     218                     host=self._ip,
#
# /usr/lib/python3.8/asyncio/tasks.py in wait_for(fut, timeout, loop)
#     479         # wait until the future completes or the timeout
#     480         try:
# --> 481             await waiter
#     482         except exceptions.CancelledError:
#     483             if fut.done():
#
# CancelledError:
# Task exception was never retrieved
# future: <Task finished name='Task-2940' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('database is locked')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 530, in _get_difference
#     where = await self.get_input_entity(types.PeerChannel(channel_id))
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 425, in get_input_entity
#     return self.session.get_input_entity(peer)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/memory.py", line 216, in get_input_entity
#     result = self.get_entity_rows_by_id(key, exact)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 323, in get_entity_rows_by_id
#     return self._execute(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 239, in _execute
#     return c.execute(stmt, values).fetchone()
# sqlite3.OperationalError: database is locked

# %%
from telethon.sync import TelegramClient
from telethon.tl.functions.messages import GetDialogsRequest
from telethon.tl.types import InputPeerEmpty, InputPeerChannel, InputPeerUser
from telethon.errors.rpcerrorlist import PeerFloodError, UserPrivacyRestrictedError
from telethon.tl.functions.channels import InviteToChannelRequest
import sys
import csv
import traceback
import time


api_id = 2420653
api_hash = 'cf6d7d2c4b0c95e7ffe555079871e579'
phone = '+918124992738'
client = TelegramClient(phone, api_id, api_hash)

await client.connect()
if not await client.is_user_authorized():
    await client.send_code_request(phone)
    await client.sign_in(phone, input('Enter the code: '))

users = []

input_file = 'members.csv'

with open(input_file, encoding='UTF-8') as f:
    rows = csv.reader(f,delimiter=",",lineterminator="\n")
    next(rows, None)
    for row in rows:
        user = {}
        user['username'] = row[0]
        user['id'] = int(row[1])
        user['access_hash'] = int(row[2])
        user['name'] = row[3]
        users.append(user)
        
chats = []
last_date = None
chunk_size = 200
groups=[]
 
result = await client(GetDialogsRequest(
             offset_date=last_date,
             offset_id=0,
             offset_peer=InputPeerEmpty(),
             limit=chunk_size,
             hash = 0
         ))
chats.extend(result.chats)
 
for chat in chats:
    try:
        if chat.megagroup== True:
            groups.append(chat)
    except:
        continue
        
print('Choose a group to add members:')
i=0
for group in groups:
    print(str(i) + '- ' + group.title)
    i+=1
    
g_index = input("Enter a Number: ")
target_group=groups[int(g_index)]
 
target_group_entity = InputPeerChannel(target_group.id,target_group.access_hash)

print('Fetching Members...')
all_participants = []
all_participants = await client.get_participants(target_group, aggressive=True)
print('Saving In file...')
with open("members.csv","w",encoding='UTF-8') as f:
    writer = csv.writer(f,delimiter=",",lineterminator="\n")
    writer.writerow(['username','user id', 'access hash','name','group', 'group id'])
    for user in all_participants:
        if user.username:
            username= user.username
        else:
            username= ""
        if user.first_name:
            first_name= user.first_name
        else:
            first_name= ""
        if user.last_name:
            last_name= user.last_name
        else:
            last_name= ""
        name= (first_name + ' ' + last_name).strip()
        writer.writerow([username,user.id,user.access_hash,name,target_group.title, target_group.id])      
print('Members scraped successfully.')

mode = int(input("Enter 1 to add by username or 2 to add by ID: "))

n = 0
 
for user in users:
    n += 1
    if n % 50 == 0:
        sleep(900)
    try:
        print ("Adding {}".format(user['id']))
        if user['username'] == "":
                continue
        user_to_add = client.get_input_entity(user['username'])
        client(InviteToChannelRequest(target_group_entity,[user_to_add]))
        print("Waiting for 60-180 Seconds...")
        time.sleep(random.randrange(60, 180))
    except PeerFloodError:
        print("Getting Flood Error from telegram. Script is stopping now. Please try again after some time.")
    except UserPrivacyRestrictedError:
        print("The user's privacy settings do not allow you to do this. Skipping.")
    except:
        traceback.print_exc()
        print("Unexpected Error")
        continue
# Out:
# Enter the code:  81736
# Task exception was never retrieved
# future: <Task finished name='Task-1211' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1209' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task was destroyed but it is pending!
# task: <Task pending name='Task-194' coro=<MTProtoSender._send_loop() running at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/network/mtprotosender.py:458> wait_for=<Future pending cb=[<TaskWakeupMethWrapper object at 0x7fa2f2d0eb20>()]>>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-195' coro=<MTProtoSender._recv_loop() running at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/network/mtprotosender.py:501> wait_for=<Future pending cb=[<TaskWakeupMethWrapper object at 0x7fa2f2b28970>()]>>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-192' coro=<Connection._send_loop() running at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/network/connection/connection.py:306> wait_for=<Future pending cb=[<TaskWakeupMethWrapper object at 0x7fa2f2b2fdc0>()]>>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-193' coro=<Connection._recv_loop() running at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/network/connection/connection.py:324> wait_for=<Future pending cb=[<TaskWakeupMethWrapper object at 0x7fa2f2d1cbe0>()]>>
# Choose a group to add members:
# 0- Royapuram Entrepreneurs🤘
# 1- StartupLanes.com
# 2- Entrepreneurial journey (EJ) | Startup Monk
# 3- KaroStartup
# 4- STARTUP FOUNDERS & Entrepreneurs | Apex Founders
# 5- Bot testing
# 6- Madhavaram Joly Group
# 7- Freelance Buddy
# 8- GLOBAL CRYPTO INVEST
# 9- African Business Network
# 10- BotCapsule [Automate Everything]
# 11- ❤️Make money every day
# 12- Legends of Tomorrow🪂🏄‍♂ Chennai Edition
# Enter a Number:  13
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-36b77a8318d4> in <module>
#      63
#      64 g_index = input("Enter a Number: ")
# ---> 65 target_group=groups[int(g_index)]
#      66
#      67 target_group_entity = InputPeerChannel(target_group.id,target_group.access_hash)
#
# IndexError: list index out of range

# %%
print(groups[])
# Out:
# [<telethon.tl.types.Channel object at 0x7fa2f2a8a0d0>, <telethon.tl.types.Channel object at 0x7fa2f24f7dc0>, <telethon.tl.types.Channel object at 0x7fa2f24f7d30>, <telethon.tl.types.Channel object at 0x7fa2f24f7190>, <telethon.tl.types.Channel object at 0x7fa2f24f74c0>, <telethon.tl.types.Channel object at 0x7fa2f24f70d0>, <telethon.tl.types.Channel object at 0x7fa2f24643d0>, <telethon.tl.types.Channel object at 0x7fa2f2464880>, <telethon.tl.types.Channel object at 0x7fa2f24646d0>, <telethon.tl.types.Channel object at 0x7fa2f2464f10>, <telethon.tl.types.Channel object at 0x7fa2f2484520>, <telethon.tl.types.Channel object at 0x7fa2f24845e0>, <telethon.tl.types.ChannelForbidden object at 0x7fa2f2484a30>]

# %%
groups[0].id
# Out:
# 1369115731

# %%
groups[0].title
# Out:
# 'Royapuram Entrepreneurs🤘'

# %%
groups[0].access_hash
# Out:
# -4683049040197455615
# Task exception was never retrieved
# future: <Task finished name='Task-1311' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1301' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1309' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1299' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1303' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1307' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1341' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1342' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1343' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1340' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1345' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1349' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1358' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1354' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1351' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1356' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1359' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1360' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1357' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1363' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1355' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1362' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1364' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1375' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1384' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1381' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1376' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1380' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1385' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1379' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1382' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1386' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1387' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1426' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 538, in _get_difference
#     result = await self(functions.channels.GetFullChannelRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1425' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 538, in _get_difference
#     result = await self(functions.channels.GetFullChannelRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1431' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 538, in _get_difference
#     result = await self(functions.channels.GetFullChannelRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1430' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 538, in _get_difference
#     result = await self(functions.channels.GetFullChannelRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1427' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 538, in _get_difference
#     result = await self(functions.channels.GetFullChannelRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1429' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 538, in _get_difference
#     result = await self(functions.channels.GetFullChannelRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1439' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1437' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1434' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database
# Task exception was never retrieved
# future: <Task finished name='Task-1438' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('attempt to write a readonly database')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: attempt to write a readonly database

# %%
dialogs = await client.get_dialogs()
first = dialogs[0]
print(first.title)
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-381' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('database is locked')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 538, in _get_difference
#     result = await self(functions.channels.GetFullChannelRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: database is locked
# Task exception was never retrieved
# future: <Task finished name='Task-383' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('database is locked')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: database is locked
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-90-44fb39add557> in <module>
# ----> 1 dialogs = await client.get_dialogs()
#       2 first = dialogs[0]
#       3 print(first.title)
#
# ~/.local/lib/python3.8/site-packages/telethon/client/dialogs.py in get_dialogs(self, *args, **kwargs)
#     254                 archived = await client.get_dialogs(archived=True)
#     255         """
# --> 256         return await self.iter_dialogs(*args, **kwargs).collect()
#     257
#     258     get_dialogs.__signature__ = inspect.signature(iter_dialogs)
#
# ~/.local/lib/python3.8/site-packages/telethon/requestiter.py in collect(self)
#     111         """
#     112         result = helpers.TotalList()
# --> 113         async for message in self:
#     114             result.append(message)
#     115
#
# ~/.local/lib/python3.8/site-packages/telethon/requestiter.py in __anext__(self)
#      72             self.index = 0
#      73             self.buffer = []
# ---> 74             if await self._load_next_chunk():
#      75                 self.left = len(self.buffer)
#      76
#
# ~/.local/lib/python3.8/site-packages/telethon/client/dialogs.py in _load_next_chunk(self)
#      51     async def _load_next_chunk(self):
#      52         self.request.limit = min(self.left, _MAX_CHUNK_SIZE)
# ---> 53         r = await self.client(self.request)
#      54
#      55         self.total = getattr(r, 'count', len(r.dialogs))
#
# ~/.local/lib/python3.8/site-packages/telethon/client/users.py in __call__(self, request, ordered)
#      28 class UserMethods:
#      29     async def __call__(self: 'TelegramClient', request, ordered=False):
# ---> 30         return await self._call(self._sender, request, ordered=ordered)
#      31
#      32     async def _call(self: 'TelegramClient', sender, request, ordered=False):
#
# ~/.local/lib/python3.8/site-packages/telethon/client/users.py in _call(self, sender, request, ordered)
#      78                 else:
#      79                     result = await future
# ---> 80                     self.session.process_entities(result)
#      81                     self._entity_cache.add(result)
#      82                     return result
#
# ~/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py in process_entities(self, tlo)
#     285             now_tup = (int(time.time()),)
#     286             rows = [row + now_tup for row in rows]
# --> 287             c.executemany(
#     288                 'insert or replace into entities values (?,?,?,?,?,?)', rows)
#     289         finally:
#
# OperationalError: database is locked
# Task exception was never retrieved
# future: <Task finished name='Task-384' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('database is locked')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 538, in _get_difference
#     result = await self(functions.channels.GetFullChannelRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: database is locked
# Task exception was never retrieved
# future: <Task finished name='Task-386' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('database is locked')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 414, in _dispatch_update
#     await self.get_me(input_peer=True)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 156, in get_me
#     me = (await self(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: database is locked
# Task exception was never retrieved
# future: <Task finished name='Task-389' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('database is locked')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: database is locked
# Task exception was never retrieved
# future: <Task finished name='Task-388' coro=<UpdateMethods._dispatch_update() done, defined at /home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py:383> exception=OperationalError('database is locked')>
# Traceback (most recent call last):
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 392, in _dispatch_update
#     await self._get_difference(update, channel_id, pts_date)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/updates.py", line 544, in _get_difference
#     result = await self(functions.updates.GetChannelDifferenceRequest(
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 30, in __call__
#     return await self._call(self._sender, request, ordered=ordered)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/client/users.py", line 80, in _call
#     self.session.process_entities(result)
#   File "/home/nivethithan/.local/lib/python3.8/site-packages/telethon/sessions/sqlite.py", line 287, in process_entities
#     c.executemany(
# sqlite3.OperationalError: database is locked

# %%
await client.connect()
if not await client.is_user_authorized():
    await client.send_code_request(phone)
    await client.sign_in(phone, input('Enter the code: '))
# Out:
# Enter the code:  72838

# %%
import sys
import csv

input_file = sys.argv[1]
users = []
with open(input_file, encoding='UTF-8') as f:
    rows = csv.reader(f,delimiter=",",lineterminator="\n")
    next(rows, None)
    for row in rows:
        user = {}
        user['username'] = row[0]
        user['id'] = int(row[1])
        user['access_hash'] = int(row[2])
        user['name'] = row[3]
        users.append(user)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-3c6a3289caca> in <module>
#       4 input_file = sys.argv[1]
#       5 users = []
# ----> 6 with open(input_file, encoding='UTF-8') as f:
#       7     rows = csv.reader(f,delimiter=",",lineterminator="\n")
#       8     next(rows, None)
#
# FileNotFoundError: [Errno 2] No such file or directory: '-f'

# %%
from telethon.tl.functions.messages import GetDialogsRequest
from telethon.tl.types import InputPeerEmpty
chats = []
last_date = None
chunk_size = 200
groups=[]

result = await client(GetDialogsRequest(
             offset_date=last_date,
             offset_id=0,
             offset_peer=InputPeerEmpty(),
             limit=chunk_size,
             hash = 0
         ))
chats.append(result.chats)
# Out:
# <ipython-input-61-4b51126f789d>:8: RuntimeWarning: coroutine 'UserMethods.__call__' was never awaited
#   result = await client(GetDialogsRequest(
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
chats
# Out:
# [[<telethon.tl.types.Channel at 0x7f50e92ead60>,
#   <telethon.tl.types.Channel at 0x7f50e92eafd0>,
#   <telethon.tl.types.ChatForbidden at 0x7f50e9389520>,
#   <telethon.tl.types.Channel at 0x7f50e92eb280>,
#   <telethon.tl.types.Channel at 0x7f50e92eb490>,
#   <telethon.tl.types.ChatForbidden at 0x7f50e92eb100>,
#   <telethon.tl.types.Channel at 0x7f50e92eb730>,
#   <telethon.tl.types.ChatForbidden at 0x7f50e92eb5b0>,
#   <telethon.tl.types.Channel at 0x7f50e92eb9d0>,
#   <telethon.tl.types.ChatForbidden at 0x7f50e92eba30>,
#   <telethon.tl.types.Channel at 0x7f50e92ebaf0>,
#   <telethon.tl.types.Channel at 0x7f50e92ebe20>,
#   <telethon.tl.types.ChatForbidden at 0x7f50e92ebac0>,
#   <telethon.tl.types.Channel at 0x7f50e92f00d0>,
#   <telethon.tl.types.ChatForbidden at 0x7f50e92f0130>,
#   <telethon.tl.types.Chat at 0x7f50e92f01c0>,
#   <telethon.tl.types.Channel at 0x7f50e92f0430>,
#   <telethon.tl.types.ChatForbidden at 0x7f50e92f02b0>,
#   <telethon.tl.types.Channel at 0x7f50e92f06a0>,
#   <telethon.tl.types.ChatForbidden at 0x7f50e92f0700>,
#   <telethon.tl.types.Channel at 0x7f50e92f07c0>,
#   <telethon.tl.types.Channel at 0x7f50e92f0970>,
#   <telethon.tl.types.Channel at 0x7f50e92f0af0>,
#   <telethon.tl.types.Channel at 0x7f50e92f0d60>,
#   <telethon.tl.types.Chat at 0x7f50e92f0df0>,
#   <telethon.tl.types.Channel at 0x7f50e92f0f40>,
#   <telethon.tl.types.Chat at 0x7f50e92f2100>,
#   <telethon.tl.types.Chat at 0x7f50e92f21f0>,
#   <telethon.tl.types.Chat at 0x7f50e92f22e0>,
#   <telethon.tl.types.Channel at 0x7f50e92f2580>,
#   <telethon.tl.types.ChatForbidden at 0x7f50e92f2340>,
#   <telethon.tl.types.ChannelForbidden at 0x7f50e92f2670>,
#   <telethon.tl.types.Channel at 0x7f50e92f26d0>]]

# %%
for chat in chats:
    try:
        if chat.megagroup == True:
            groups.append(chat)
    except:
        continue

# %%
print('Choose a group to add members:')
i=0
for group in groups:
    print(str(i) + '- ' + group.title)
    i+=1
# Out:
# Choose a group to add members:

# %%
g_index = input("Enter a Number: ")
target_group=groups[int(g_index)]
# Out:
# Enter a Number:  0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-66-37b99fb778dd> in <module>
#       1 g_index = input("Enter a Number: ")
# ----> 2 target_group=groups[int(g_index)]
#
# IndexError: list index out of range

# %%
from telethon.tl.functions.channels import InviteToChannelRequest

# %%
user_to_add = await client.get_input_entity(user['username'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-f7ec37c77688> in <module>
# ----> 1 user_to_add = await client.get_input_entity(user['username'])
#
# TypeError: 'coroutine' object is not subscriptable

# %%
for user in users:
    try:
        print ("Adding {}".format(user['id']))
        if mode == 1:
            if user['username'] == "":
                continue
            user_to_add = client.get_input_entity(user['username'])
        elif mode == 2:
            user_to_add = InputPeerUser(user['id'], user['access_hash'])
        else:
            sys.exit("Invalid Mode Selected. Please Try Again.")
        client(InviteToChannelRequest(target_group_entity,[user_to_add]))
        print("Waiting 60 Seconds...")
        time.sleep(60)
    except PeerFloodError:
        print("Getting Flood Error from telegram. Script is stopping now. Please try again after some time.")
    except UserPrivacyRestrictedError:
        print("The user's privacy settings do not allow you to do this. Skipping.")
    except:
        traceback.print_exc()
        print("Unexpected Error")
        continue
