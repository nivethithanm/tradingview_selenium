# %%
# import libraries
from bs4 import BeautifulSoup
import mechanize

def getContact():
    users = []
    members_input_file = 'members.csv'
        with open(members_input_file, 'r+', encoding='UTF-8') as f:
            rows = csv.reader(f,delimiter=",",lineterminator="\n")
            next(rows, None)
            for row in rows:
                user = {}
                user['username'] = row[0]
                user['id'] = int(row[1])
                user['access_hash'] = int(row[2])
                user['name'] = row[3]
                users.append(user)
    
        
    mc = mechanize.Browser()
    mc.set_handle_robots(False)
 
    url = 'https://www.findandtrace.com/trace-mobile-number-location'
    mc.open(url)
 
    mc.select_form(name='trace')
    mc['mobilenumber'] = '8124992738' # Enter a mobile number
    res = mc.submit().read()
 
    soup = BeautifulSoup(res,'html.parser')
    tbl = soup.find_all('table',class_='shop_table')
    #print(tbl)


    data = tbl[0].find('tfoot')
    c=0
    for i in data:
        c+=1
        if c in (1,4,6,8):
            continue
        th = i.find('th')
        td = i.find('td')
        print(th.text,td.text)
 
 
    data = tbl[1].find('tfoot')
    c=0
    for i in data:
        c+=1
        if c in (2,20,22,26): 
            th = i.find('th')
            td = i.find('td')
            print(th.text,td.text)
        

        
    input_file = 'contacts.csv'
    with open(input_file,'w+',encoding='UTF-8') as f:
            writer = csv.writer(f,delimiter=",",lineterminator="\n")
            csv_dict = [row for row in csv.DictReader(f)]
            if len(csv_dict) == 0:
                writer.writerow(['Name','Phone Number', 'Telecom Circle', 'Network', 'Main Language'])
            for user in users:
                writer.writerow([user['name'],user['phone'],user['telecom_circle'],user['network'],user['main_language']]) 
                
    
    
mc = mechanize.Browser()
mc.set_handle_robots(False)
 
url = 'https://www.findandtrace.com/trace-mobile-number-location'
mc.open(url)
 
mc.select_form(name='trace')
mc['mobilenumber'] = '8124992738' # Enter a mobile number
res = mc.submit().read()
 
soup = BeautifulSoup(res,'html.parser')
tbl = soup.find_all('table',class_='shop_table')
#print(tbl)


data = tbl[0].find('tfoot')
c=0
for i in data:
    c+=1
    if c in (1,4,6,8):
        continue
    th = i.find('th')
    td = i.find('td')
    print(th.text,td.text)
 
 
data = tbl[1].find('tfoot')
c=0
for i in data:
    c+=1
    if c in (2,20,22,26): 
        th = i.find('th')
        td = i.find('td')
        print(th.text,td.text)
# Out:
# Mobile Phone: 8124992738
# Telecoms Circle / State Tamilnadu
# Network : IDEA
# Service Type / Signal: GSM
# Connection Status:  LIVE - Active
# +91 8124992738 - SIM card distributed at   Coimbatore, Madurai, Tirchy, Salem, Tirunelveli, Tirupur, Kanchipuram
# Circle Capital : Chennai
# Main Language in the telecoms circle : Tamil
# Local time at phone location : 08/02/21 22:05:57 : Hours

# %%
# import libraries
from bs4 import BeautifulSoup
import mechanize
import csv
import nest_asyncio

nest_asyncio.apply()

def getContact():
    users = []
    contacts = []
    members_input_file = 'members.csv'
    with open(members_input_file, 'r+', encoding='UTF-8') as f:
        rows = csv.reader(f,delimiter=",",lineterminator="\n")
        next(rows, None)
        for row in rows:
            user = {}
            user['username'] = row[0]
            user['id'] = int(row[1])
            user['access_hash'] = int(row[2])
            user['name'] = row[3]
            users.append(user)    
    for user in users:
        mc = mechanize.Browser()
        mc.set_handle_robots(False) 
        url = 'https://www.findandtrace.com/trace-mobile-number-location'
        mc.open(url) 
        mc.select_form(name='trace')
        try:
            mc['mobilenumber'] = user['id'] # Enter a mobile number
            res = mc.submit().read()
        except:
            continue
        soup = BeautifulSoup(res,'html.parser')
        tbl = soup.find_all('table',class_='shop_table')
        #print(tbl)        
        contact['phone'] = user['id']
        data = tbl[0].find('tfoot')
        c=0
        for i in data:
            c+=1
            if c in (1,4,6,8):
                continue
            if (c == 3):
                contact['Circle'] = i.find('td').text
            if (c == 5):
                contact['Network'] = i.find('td').text
            if (c > 8):
                contact['Connection'] = i.find('td').text
            #th = i.find('th')
            #td = i.find('td')
            #print(th.text,td.text) 
        data = tbl[1].find('tfoot')
        c=0
        for i in data:
            c+=1
            if(c==22):
                contact['main_languange'] = i.find('td').text
                #th = i.find('th')
                #td = i.find('td')
                #print(th.text,td.text)
        contacts.append(contact)        
    input_file = 'contacts.csv'
    with open(input_file,'w+',encoding='UTF-8') as f:
            writer = csv.writer(f,delimiter=",",lineterminator="\n")
            csv_dict = [row for row in csv.DictReader(f)]
            if len(csv_dict) == 0:
                writer.writerow(['Name','Phone Number', 'Telecom Circle', 'Network', 'Main Language'])
            for user in contacts:
                writer.writerow([user['name'],user['phone'],user['Circle'], user['Connection'],user['network'],user['main_language']]) 
                
loop = asyncio.get_event_loop()
loop.run_until_complete(getContact())

# %%
from bs4 import BeautifulSoup
import mechanize
import csv

users = []
contacts = []
members_input_file = 'members.csv'
with open(members_input_file, 'r+', encoding='UTF-8') as f:
        rows = csv.reader(f,delimiter=",",lineterminator="\n")
        next(rows, None)
        for row in rows:
            user = {}
            user['username'] = row[0]
            user['id'] = int(row[1])
            user['access_hash'] = int(row[2])
            user['name'] = row[3]
            users.append(user)    
for user in users:
        mc = mechanize.Browser()
        mc.set_handle_robots(False) 
        url = 'https://www.findandtrace.com/trace-mobile-number-location'
        mc.open(url) 
        mc.select_form(name='trace')
        try:
            mc['mobilenumber'] = user['id'] # Enter a mobile number
            res = mc.submit().read()
        except:
            continue
        soup = BeautifulSoup(res,'html.parser')
        tbl = soup.find_all('table',class_='shop_table')
        #print(tbl)        
        contact['phone'] = user['id']
        data = tbl[0].find('tfoot')
        c=0
        for i in data:
            c+=1
            if c in (1,4,6,8):
                continue
            if (c == 3):
                contact['Circle'] = i.find('td').text
            if (c == 5):
                contact['Network'] = i.find('td').text
            if (c > 8):
                contact['Connection'] = i.find('td').text
            #th = i.find('th')
            #td = i.find('td')
            #print(th.text,td.text) 
        data = tbl[1].find('tfoot')
        c=0
        for i in data:
            c+=1
            if(c==22):
                contact['main_languange'] = i.find('td').text
                #th = i.find('th')
                #td = i.find('td')
                #print(th.text,td.text)
        contacts.append(contact)        
input_file = 'contacts.csv'
with open(input_file,'w+',encoding='UTF-8') as f:
            writer = csv.writer(f,delimiter=",",lineterminator="\n")
            csv_dict = [row for row in csv.DictReader(f)]
            if len(csv_dict) == 0:
                writer.writerow(['Name','Phone Number', 'Telecom Circle', 'Network', 'Main Language'])
            for user in contacts:
                writer.writerow([user['name'],user['phone'],user['Circle'], user['Connection'],user['network'],user['main_language']])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-44a0259befcb> in <module>
#      21         url = 'https://www.findandtrace.com/trace-mobile-number-location'
#      22         mc.open(url)
# ---> 23         mc.select_form(name='trace')
#      24         try:
#      25             mc['mobilenumber'] = user['id'] # Enter a mobile number
#
# ~/.local/lib/python3.8/site-packages/mechanize/_mechanize.py in select_form(self, name, predicate, nr, **attrs)
#     631                 "at least one argument must be supplied to specify form")
#     632
# --> 633         global_form = self._factory.global_form
#     634         if nr is None and name is None and predicate is not None and predicate(
#     635                 global_form):
#
# ~/.local/lib/python3.8/site-packages/mechanize/_html.py in global_form(self)
#     311     def global_form(self):
#     312         if self._current_global_form is lazy:
# --> 313             self.forms()
#     314         return self._current_global_form
#     315
#
# ~/.local/lib/python3.8/site-packages/mechanize/_html.py in forms(self)
#     318         # this implementation sets .global_form as a side-effect
#     319         if self._current_forms is lazy:
# --> 320             self._current_forms, self._current_global_form = self._get_forms()
#     321         return self._current_forms
#     322
#
# ~/.local/lib/python3.8/site-packages/mechanize/_html.py in _get_forms(self)
#     333
#     334     def _get_forms(self):
# --> 335         if self.root is None:
#     336             return (), None
#     337         return parse_forms(self.root,
#
# ~/.local/lib/python3.8/site-packages/mechanize/_html.py in root(self)
#     287         if self._root is lazy:
#     288             response = self._response
# --> 289             raw = self._response.read() if self._response else b''
#     290             default_encoding = self._encoding_finder._default_encoding
#     291             transport_encoding = get_encoding_from_response(response, verify=False)
#
# ~/.local/lib/python3.8/site-packages/mechanize/_response.py in read(self, size)
#     197         self.__cache.seek(0, 2)
#     198         if size == -1:
# --> 199             self.__cache.write(self.wrapped.read())
#     200             self.read_complete = True
#     201         else:
#
# /usr/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# /usr/lib/python3.8/http/client.py in readinto(self, b)
#     490
#     491         if self.chunked:
# --> 492             return self._readinto_chunked(b)
#     493
#     494         if self.length is not None:
#
# /usr/lib/python3.8/http/client.py in _readinto_chunked(self, b)
#     590
#     591                 if len(mvb) <= chunk_left:
# --> 592                     n = self._safe_readinto(mvb)
#     593                     self.chunk_left = chunk_left - n
#     594                     return total_bytes + n
#
# /usr/lib/python3.8/http/client.py in _safe_readinto(self, b)
#     618         """Same as _safe_read, but for reading into a buffer."""
#     619         amt = len(b)
# --> 620         n = self.fp.readinto(b)
#     621         if n < amt:
#     622             raise IncompleteRead(bytes(b[:n]), amt-n)
#
# /usr/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# /usr/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
